# %%
df
# Out:
#            Date        Open        High         Low       Close    Volume
# 0    2015-02-17  127.489998  128.880005  126.919998  127.830002  63152400  \
# 1    2015-02-18  127.629997  128.779999  127.449997  128.720001  44891700
# 2    2015-02-19  128.479996  129.029999  128.330002  128.449997  37362400
# 3    2015-02-20  128.619995  129.500000  128.050003  129.500000  48948400
# 4    2015-02-23  130.020004  133.000000  129.660004  133.000000  70974100
# ..          ...         ...         ...         ...         ...       ...
# 501  2017-02-10  132.460007  132.940002  132.050003  132.119995  20065500
# 502  2017-02-13  133.080002  133.820007  132.750000  133.289993  23035400
# 503  2017-02-14  133.470001  135.089996  133.250000  135.020004  32815500
# 504  2017-02-15  135.520004  136.270004  134.619995  135.509995  35501600
# 505  2017-02-16  135.669998  135.899994  134.839996  135.350006  22118000
#
#        Adjusted          dn        mavg          up   direction
# ...

# %%
import plotly.graph_objects as go

import pandas as pd

# Load data
df = pd.read_csv(
    "https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv")
df.columns = [col.replace("AAPL.", "") for col in df.columns]

# Create figure
fig = go.Figure()

fig.add_trace(
    go.Scatter(x=list(df.Date), y=list(df.High)))

# Set title
fig.update_layout(
    title_text="Time series with range slider and selectors"
)

# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     stepmode="backward"),
                dict(count=6,
                     label="6m",
                     step="month",
                     stepmode="backward"),
                dict(count=1,
                     label="YTD",
                     step="year",
                     stepmode="todate"),
                dict(count=1,
                     label="1y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig.show()

# %%
import plotly.graph_objects as go
import numpy as np
import pandas as pd

frames        = np.arange(0, 600, 1/30) #time in frames
fluoresence   = np.sin(frames)

data = {"frames": frames, "fluoresence": fluoresence}
df = pd.DataFrame(data)

# %%
df
# Out:
#            frames  fluoresence
# 0        0.000000     0.000000
# 1        0.033333     0.033327
# 2        0.066667     0.066617
# 3        0.100000     0.099833
# 4        0.133333     0.132939
# ...           ...          ...
# 17995  599.833333     0.209304
# 17996  599.866667     0.176599
# 17997  599.900000     0.143698
# 17998  599.933333     0.110637
# 17999  599.966667     0.077453
#
# [18000 rows x 2 columns]

# %%
# Create figure
fig = go.Figure()

fig.add_trace(
    go.Scatter(x=list(df.frames), y=list(df.fluoresence)))

# Set title
fig.update_layout(
    title_text="Time series with range slider and selectors"
)
fps = 30
# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=fps*1,
                     label="1s",
                     step="second",
                     stepmode="backward"),
                dict(count=fps*5,
                     label="5s",
                     step="second",
                     stepmode="backward"),
                dict(count=fps*30,
                     label="30s",
                     step="second",
                     stepmode="backward"),
                dict(count=fps*60,
                     label="1m",
                     step="second",
                     stepmode="backward"),
                dict(count=fps*300,
                     label="5m",
                     step="second",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="time"
    )
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 13
#      11 fps = 30
#      12 # Add range slider
# ---> 13 fig.update_layout(
#      14     xaxis=dict(
#      15         rangeselector=dict(
#      16             buttons=list([
#      17                 dict(count=fps*1,
#      18                      label="1s",
#      19                      step="second",
#      20                      stepmode="backward"),
#      21                 dict(count=fps*5,
#      22                      label="5s",
#      23                      step="second",
#      24                      stepmode="backward"),
#      25                 dict(count=fps*30,
#      26                      label="30s",
#      27                      step="second",
#      28                      stepmode="backward"),
#      29                 dict(count=fps*60,
# ...

# %%
# !pip install dash
# Out:
# ...
#      --------------------------------------- 10.4/10.4 MB 29.7 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 101.8/101.8 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 233.6/233.6 kB ? eta 0:00:00
# ...
#      -------------------------------------- 133.1/133.1 kB 7.7 MB/s eta 0:00:00
# ...

# %%
import plotly.graph_objects as go # or plotly.express as px
fig = go.Figure() # or any Plotly Express function e.g. px.bar(...)
# fig.add_trace( ... )
# fig.update_layout( ... )

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash import Dash, html, dcc, Input, Output, callback

app = dash.Dash()
app.layout = html.Div([
    dcc.Graph(figure=fig),
    dcc.RangeSlider(0, 20, 1, value=[5, 15], id='time-range'),
    html.Div(id='output-container-range-slider')
])

@callback(
    Output('output-container-range-slider', 'children'),
    Input('time-range', 'value'))
def update_output(value):
    return 'You have selected "{}"'.format(value)

app.run_server(debug=True, use_reloader=False)  # Turn off reloader if inside Jupyter
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
